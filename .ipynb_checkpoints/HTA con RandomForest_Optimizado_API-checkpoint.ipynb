# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from sklearn.metrics import accuracy_score
dataframe = pd.read_csv('Hipertension_Arterial_Mexico_balanced.csv')

# %%
dataframe.head(10)
# Out:
#    sexo  edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0   1.0  55.0                      166.0                   9.0
# 1   2.0  43.0                      142.0                  22.0
# 2   2.0  35.0                      142.0                  22.0
# 3   2.0  50.0                      142.0                  22.0
# 4   2.0  26.0                      141.0                  20.0
# 5   1.0  51.0                       15.0                  22.0
# 6   1.0  44.0                      142.0                  22.0
# 7   1.0  62.0                      142.0                  22.0
# 8   2.0  54.0                      142.0                  22.0
# 9   1.0  56.0                      146.0                  25.0
#
#    valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0                7.0            42.0                  35.0
# 1               48.0             4.0                  34.0
# 2               48.0             4.0                  34.0
# 3               48.0             4.0                  34.0
# 4               46.0            43.0                  53.0
# 5               64.0             3.0                  24.0
# 6               48.0             4.0                  34.0
# 7               48.0             4.0                  34.0
# 8               48.0             4.0                  34.0
# 9               61.0            31.0                  30.0
#
#    valor_colesterol_ldl  valor_colesterol_total  valor_creatina  ...  \
# 0                 132.0                   224.0            93.0  ...
# 1                  86.0                   139.0            58.0  ...
# 2                  86.0                   139.0            58.0  ...
# 3                  86.0                   139.0            58.0  ...
# 4                  57.0                   127.0            58.0  ...
# 5                  75.0                   104.0            75.0  ...
# 6                  86.0                   139.0            58.0  ...
# 7                  86.0                   139.0            58.0  ...
# 8                  86.0                   139.0            58.0  ...
# 9                  62.0                   109.0             7.0  ...
#
#    segundamedicion_peso  segundamedicion_estatura  distancia_rodilla_talon  \
# 0                 647.0                     154.0                    485.0
# 1                 647.0                     154.0                    485.0
# 2                 647.0                     154.0                    485.0
# 3                 647.0                     154.0                    485.0
# 4                 647.0                     154.0                    485.0
# 5                 647.0                     154.0                    485.0
# 6                 647.0                     154.0                    485.0
# 7                 647.0                     154.0                    485.0
# 8                 647.0                     154.0                    485.0
# 9                 647.0                     154.0                    485.0
#
#    circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 0                             335.0                      0.0
# 1                             335.0                      0.0
# 2                             335.0                      0.0
# 3                             335.0                      0.0
# 4                             335.0                      0.0
# 5                             335.0                      0.0
# 6                             335.0                      0.0
# 7                             335.0                      0.0
# 8                             335.0                      0.0
# 9                             335.0                      0.0
#
#    tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 0             124.0          4.0   3.305242e+09              1.0
# 1             106.0          4.0   2.479548e+08              0.0
# 2             117.0          3.0   4.753759e+09              2.0
# 3             112.0          2.0   2.980299e+09              1.0
# 4             120.0          4.0   2.090747e+09              2.0
# 5             138.0          3.0   3.663991e+09              2.0
# 6             108.0          2.0   3.247727e+09              2.0
# 7              88.0          4.0   2.322393e+08              2.0
# 8             158.0          3.0   2.815582e+08              2.0
# 9             128.0          1.0   2.883057e+09              2.0
#
#    riesgo_hipertension
# 0                  1.0
# 1                  1.0
# 2                  1.0
# 3                  1.0
# 4                  0.0
# 5                  1.0
# 6                  1.0
# 7                  0.0
# 8                  1.0
# 9                  1.0
#
# [10 rows x 35 columns]

# %%
dataframe.describe()
# Out:
#               sexo        edad  concentracion_hemoglobina  \
# count  2892.000000  2892.00000                2892.000000
# mean      1.587879    42.06274                 137.083513
# std       0.462769    10.72524                  26.448494
# min       1.000000     4.00000                   8.000000
# 25%       1.000000    34.00000                 142.000000
# 50%       2.000000    43.00000                 142.000000
# 75%       2.000000    51.00000                 142.000000
# max       2.000000    88.00000                 199.000000
#
#        temperatura_ambiente  valor_acido_urico  valor_albumina  \
# count           2892.000000        2892.000000     2892.000000
# mean              21.481069          46.225169       12.688657
# std                2.954528          10.076038       14.020317
# min                3.000000           2.000000        2.000000
# 25%               22.000000          48.000000        4.000000
# 50%               22.000000          48.000000        4.000000
# 75%               22.000000          48.000000       22.000000
# max               35.000000          95.000000       49.000000
#
#        valor_colesterol_hdl  valor_colesterol_ldl  valor_colesterol_total  \
# count           2892.000000           2892.000000             2892.000000
# mean              36.268552             86.355221              142.405686
# std                8.293784             16.261262               26.159034
# min               13.000000             11.000000               41.000000
# 25%               34.000000             86.000000              139.000000
# 50%               34.000000             86.000000              139.000000
# 75%               35.010815             86.000000              139.000000
# max              279.000000            303.000000              681.000000
#
#        valor_creatina  ...  segundamedicion_peso  segundamedicion_estatura  \
# count     2892.000000  ...                2892.0                    2892.0
# mean        59.033427  ...                 647.0                     154.0
# std         18.665248  ...                   0.0                       0.0
# min          1.000000  ...                 647.0                     154.0
# 25%         58.000000  ...                 647.0                     154.0
# 50%         58.000000  ...                 647.0                     154.0
# 75%         58.000000  ...                 647.0                     154.0
# max        496.000000  ...                 647.0                     154.0
#
#        distancia_rodilla_talon  circunferencia_de_la_pantorrilla  \
# count                   2892.0                            2892.0
# mean                     485.0                             335.0
# std                        0.0                               0.0
# min                      485.0                             335.0
# 25%                      485.0                             335.0
# 50%                      485.0                             335.0
# 75%                      485.0                             335.0
# max                      485.0                             335.0
#
#        segundamedicion_cintura  tension_arterial  sueno_horas  masa_corporal  \
# count                   2892.0        2892.00000  2892.000000   2.892000e+03
# mean                       0.0         118.55837     3.226430   2.383618e+09
# std                        0.0          17.71747     1.079416   9.487024e+08
# min                        0.0          80.00000     1.000000   3.431900e+04
# 25%                        0.0         106.00000     2.299598   2.154015e+09
# 50%                        0.0         116.00000     3.197881   2.426780e+09
# 75%                        0.0         128.00000     4.000000   2.942704e+09
# max                        0.0         200.00000     5.000000   9.191461e+09
#
#        actividad_total  riesgo_hipertension
# count      2892.000000          2892.000000
# mean          1.680175             0.500000
# std           0.612463             0.500086
# min           0.000000             0.000000
# 25%           1.000000             0.000000
# 50%           2.000000             0.500000
# 75%           2.000000             1.000000
# max           4.000000             1.000000
#
# [8 rows x 35 columns]

# %%
dataframe.groupby('riesgo_hipertension').size()
# Out:
# riesgo_hipertension
# 0.0    1446
# 1.0    1446
# dtype: int64

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2892 entries, 0 to 2891
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   sexo                              2892 non-null   float64
#  1   edad                              2892 non-null   float64
#  2   concentracion_hemoglobina         2892 non-null   float64
#  3   temperatura_ambiente              2892 non-null   float64
#  4   valor_acido_urico                 2892 non-null   float64
#  5   valor_albumina                    2892 non-null   float64
#  6   valor_colesterol_hdl              2892 non-null   float64
#  7   valor_colesterol_ldl              2892 non-null   float64
#  8   valor_colesterol_total            2892 non-null   float64
#  9   valor_creatina                    2892 non-null   float64
#  10  resultado_glucosa                 2892 non-null   float64
#  11  valor_insulina                    2892 non-null   float64
#  12  valor_trigliceridos               2892 non-null   float64
#  13  resultado_glucosa_promedio        2892 non-null   float64
#  14  valor_hemoglobina_glucosilada     2892 non-null   float64
#  15  valor_ferritina                   2892 non-null   float64
#  16  valor_folato                      2892 non-null   float64
#  17  valor_homocisteina                2892 non-null   float64
#  18  valor_proteinac_reactiva          2892 non-null   float64
#  19  valor_transferrina                2892 non-null   float64
#  20  valor_vitamina_bdoce              2892 non-null   float64
#  21  valor_vitamina_d                  2892 non-null   float64
#  22  peso                              2892 non-null   float64
#  23  estatura                          2892 non-null   float64
#  24  medida_cintura                    2892 non-null   float64
#  25  segundamedicion_peso              2892 non-null   float64
#  26  segundamedicion_estatura          2892 non-null   float64
#  27  distancia_rodilla_talon           2892 non-null   float64
#  28  circunferencia_de_la_pantorrilla  2892 non-null   float64
#  29  segundamedicion_cintura           2892 non-null   float64
#  30  tension_arterial                  2892 non-null   float64
#  31  sueno_horas                       2892 non-null   float64
#  32  masa_corporal                     2892 non-null   float64
#  33  actividad_total                   2892 non-null   float64
#  34  riesgo_hipertension               2892 non-null   float64
# dtypes: float64(35)
# memory usage: 790.9 KB

# %%
dataframe.describe()
# Out:
#               sexo        edad  concentracion_hemoglobina  \
# count  2892.000000  2892.00000                2892.000000
# mean      1.587879    42.06274                 137.083513
# std       0.462769    10.72524                  26.448494
# min       1.000000     4.00000                   8.000000
# 25%       1.000000    34.00000                 142.000000
# 50%       2.000000    43.00000                 142.000000
# 75%       2.000000    51.00000                 142.000000
# max       2.000000    88.00000                 199.000000
#
#        temperatura_ambiente  valor_acido_urico  valor_albumina  \
# count           2892.000000        2892.000000     2892.000000
# mean              21.481069          46.225169       12.688657
# std                2.954528          10.076038       14.020317
# min                3.000000           2.000000        2.000000
# 25%               22.000000          48.000000        4.000000
# 50%               22.000000          48.000000        4.000000
# 75%               22.000000          48.000000       22.000000
# max               35.000000          95.000000       49.000000
#
#        valor_colesterol_hdl  valor_colesterol_ldl  valor_colesterol_total  \
# count           2892.000000           2892.000000             2892.000000
# mean              36.268552             86.355221              142.405686
# std                8.293784             16.261262               26.159034
# min               13.000000             11.000000               41.000000
# 25%               34.000000             86.000000              139.000000
# 50%               34.000000             86.000000              139.000000
# 75%               35.010815             86.000000              139.000000
# max              279.000000            303.000000              681.000000
#
#        valor_creatina  ...  segundamedicion_peso  segundamedicion_estatura  \
# count     2892.000000  ...                2892.0                    2892.0
# mean        59.033427  ...                 647.0                     154.0
# std         18.665248  ...                   0.0                       0.0
# min          1.000000  ...                 647.0                     154.0
# 25%         58.000000  ...                 647.0                     154.0
# 50%         58.000000  ...                 647.0                     154.0
# 75%         58.000000  ...                 647.0                     154.0
# max        496.000000  ...                 647.0                     154.0
#
#        distancia_rodilla_talon  circunferencia_de_la_pantorrilla  \
# count                   2892.0                            2892.0
# mean                     485.0                             335.0
# std                        0.0                               0.0
# min                      485.0                             335.0
# 25%                      485.0                             335.0
# 50%                      485.0                             335.0
# 75%                      485.0                             335.0
# max                      485.0                             335.0
#
#        segundamedicion_cintura  tension_arterial  sueno_horas  masa_corporal  \
# count                   2892.0        2892.00000  2892.000000   2.892000e+03
# mean                       0.0         118.55837     3.226430   2.383618e+09
# std                        0.0          17.71747     1.079416   9.487024e+08
# min                        0.0          80.00000     1.000000   3.431900e+04
# 25%                        0.0         106.00000     2.299598   2.154015e+09
# 50%                        0.0         116.00000     3.197881   2.426780e+09
# 75%                        0.0         128.00000     4.000000   2.942704e+09
# max                        0.0         200.00000     5.000000   9.191461e+09
#
#        actividad_total  riesgo_hipertension
# count      2892.000000          2892.000000
# mean          1.680175             0.500000
# std           0.612463             0.500086
# min           0.000000             0.000000
# 25%           1.000000             0.000000
# 50%           2.000000             0.500000
# 75%           2.000000             1.000000
# max           4.000000             1.000000
#
# [8 rows x 35 columns]

# %%
import seaborn as sb
sb.catplot(x = 'riesgo_hipertension',data=dataframe,kind="count", height=2.5, aspect=.8)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Cargar el dataset balanceado
balanced_data = pd.read_csv('Hipertension_Arterial_Mexico_balanced.csv')

# Separar características y variable objetivo
y = balanced_data['riesgo_hipertension']
x = balanced_data[['masa_corporal', 'tension_arterial', 'medida_cintura', 'peso', 'actividad_total', 'edad', 'estatura', 'sexo', 'sueno_horas', 'valor_hemoglobina_glucosilada', 'valor_insulina', 'resultado_glucosa_promedio', 'concentracion_hemoglobina', 'valor_colesterol_ldl', 'valor_trigliceridos']]

# Dividir en entrenamiento y prueba (si necesitas una nueva partición)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Entrenar un modelo
model = RandomForestClassifier(n_estimators=150, max_depth=20, random_state=42)
model.fit(x_train, y_train)

# Evaluar
predicciones = model.predict(x_test)
clasificadores = {0: "Sin riesgo", 1: "Con riesgo"}
target_names = list(clasificadores.values())
print("Reporte de clasificación:")
print(classification_report(y_test, predicciones, target_names=target_names))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#   Sin riesgo       0.97      0.99      0.98       436
#   Con riesgo       0.99      0.97      0.98       432
#
#     accuracy                           0.98       868
#    macro avg       0.98      0.98      0.98       868
# weighted avg       0.98      0.98      0.98       868

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

sns.heatmap(confusion_matrix(y_test, predicciones), annot=True, fmt="d", xticklabels=clasificadores, yticklabels=clasificadores)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show();

# %%
import pickle
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
from flask import Flask, jsonify, request
from threading import Thread
import time
app = Flask(__name__)

try:
    with open('model.pkl', 'rb') as f:
        model = pickle.load(f)
    print("Modelo cargado correctamente")
except Exception as e:
    print("Error al cargar el modelo:", str(e))
    modelo = None

@app.route('/predict', methods=['POST'])
def predict():
    try:
        req_json = request.get_json()
        print("Datos recibidos en la API:", req_json)
        input_data = pd.DataFrame(req_json)
        print("DataFrame creado:", input_data.to_dict())
    except Exception as e:
        print("Error al procesar JSON:", str(e))
        return jsonify({'error': str(e)}), 400

    if input_data.empty:
        print("Error: DataFrame vacío")
        return jsonify({'error': 'No data provided'}), 400

    expected_columns = ['masa_corporal', 'tension_arterial', 'medida_cintura', 'peso', 'actividad_total', 'edad', 'estatura', 'sexo', 'sueno_horas', 'valor_hemoglobina_glucosilada', 'valor_insulina', 'resultado_glucosa_promedio', 'concentracion_hemoglobina', 'valor_colesterol_ldl', 'valor_trigliceridos']
    if not all(col in input_data.columns for col in expected_columns):
        print("Error: Columnas faltantes", input_data.columns.tolist())
        return jsonify({'error': 'Missing required columns'}), 400
    
    try:
        predictions = model.predict(input_data)
        predictions = predictions.astype(int)
        predictions = [clasificadores[pred] for pred in predictions]
        probabilities = model.predict_proba(input_data).tolist()
        print("Predicciones realizadas:", predictions)
    except Exception as e:
        print("Error al hacer predicciones:", str(e))
        return jsonify({'error': 'Prediction failed'}), 500

    response = jsonify({
        'predictions': predictions,
        'probabilities': probabilities
    })
    response.status_code = 200
    print("Respuesta enviada:", response.get_json())
    return response

def run_flask():
    app.run(port=8001, use_reloader=False)

if __name__ == '__main__':
    Thread(target=run_flask).start()
    time.sleep(3)
# Out:
# Modelo cargado correctamente
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8001
# Press CTRL+C to quit

# %%
test_data = pd.DataFrame({
    'masa_corporal': [31],
    'tension_arterial': [107],
    'medida_cintura': [88],
    'peso': [74.55],
    'actividad_total': [2],
    'edad': [41],
    'estatura': [147.3],
    'sexo': [2],
    'sueno_horas': [4],
    'valor_hemoglobina_glucosilada': [4],
    'valor_insulina': [4],
    'resultado_glucosa_promedio': [4],
    'concentracion_hemoglobina': [86],
    'valor_colesterol_ldl': [86],
    'valor_trigliceridos': [86]
})

data_json = test_data.to_json(orient='records')

print("Datos enviados en el POST:")
print(data_json)

headers = {'Content-Type': 'application/json', 'Accept': 'application/json'}

try:
    print("Enviando solicitud POST a http://localhost:8001/predict")
    response = requests.post('http://localhost:8001/predict', data=data_json, headers=headers)
    print('\nConsulta a la API:')
    print('Status:', response.status_code)
    print('Respuesta:', response.json())
except Exception as e:
    print(f"Error al consultar la API: {e}")
# Out:
# Datos enviados en el POST:
# [{"masa_corporal":31,"tension_arterial":107,"medida_cintura":88,"peso":74.55,"actividad_total":2,"edad":41,"estatura":147.3,"sexo":2,"sueno_horas":4,"valor_hemoglobina_glucosilada":4,"valor_insulina":4,"resultado_glucosa_promedio":4,"concentracion_hemoglobina":86,"valor_colesterol_ldl":86,"valor_trigliceridos":86}]
# Enviando solicitud POST a http://localhost:8001/predict
# 127.0.0.1 - - [17/May/2025 17:10:59] "POST /predict HTTP/1.1" 200 -
# Datos recibidos en la API: [{'masa_corporal': 31, 'tension_arterial': 107, 'medida_cintura': 88, 'peso': 74.55, 'actividad_total': 2, 'edad': 41, 'estatura': 147.3, 'sexo': 2, 'sueno_horas': 4, 'valor_hemoglobina_glucosilada': 4, 'valor_insulina': 4, 'resultado_glucosa_promedio': 4, 'concentracion_hemoglobina': 86, 'valor_colesterol_ldl': 86, 'valor_trigliceridos': 86}]
# DataFrame creado: {'masa_corporal': {0: 31}, 'tension_arterial': {0: 107}, 'medida_cintura': {0: 88}, 'peso': {0: 74.55}, 'actividad_total': {0: 2}, 'edad': {0: 41}, 'estatura': {0: 147.3}, 'sexo': {0: 2}, 'sueno_horas': {0: 4}, 'valor_hemoglobina_glucosilada': {0: 4}, 'valor_insulina': {0: 4}, 'resultado_glucosa_promedio': {0: 4}, 'concentracion_hemoglobina': {0: 86}, 'valor_colesterol_ldl': {0: 86}, 'valor_trigliceridos': {0: 86}}
# Predicciones realizadas: ['Sin riesgo']
# Respuesta enviada: {'predictions': ['Sin riesgo'], 'probabilities': [[0.62, 0.38]]}
#
# Consulta a la API:
# Status: 200
# Respuesta: {'predictions': ['Sin riesgo'], 'probabilities': [[0.62, 0.38]]}
