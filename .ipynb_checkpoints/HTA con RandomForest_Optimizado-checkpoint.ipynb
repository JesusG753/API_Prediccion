# %%
# Autor: Mg. Flor Elizabeth Cerdán León
# Primero importar las librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Estoy accediendo al archivo CSV y copiandolo a un dataframe
dataframe = pd.read_csv('Hipertension_Arterial_Mexico_balanced.csv')

# %%
dataframe.head(10)
# Out:
#    sexo  edad  concentracion_hemoglobina  temperatura_ambiente  \
# 0   2.0  29.0                       11.9                  22.0
# 1   2.0  35.0                        7.3                  22.0
# 2   2.0  50.0                       14.2                  22.0
# 3   1.0  24.0                       14.2                  22.0
# 4   2.0  42.0                       14.5                  10.0
# 5   1.0  20.0                       14.2                  22.0
# 6   2.0  25.0                       14.5                  15.0
# 7   2.0  23.0                       14.2                  22.0
# 8   1.0  52.0                       14.2                  22.0
# 9   1.0  44.0                       15.3                  17.0
#
#    valor_acido_urico  valor_albumina  valor_colesterol_hdl  \
# 0                2.7             3.4                  37.0
# 1                1.7             4.0                  46.0
# 2                4.8             4.0                  34.0
# 3                4.8             4.0                  34.0
# 4                5.0             4.0                  50.0
# 5                4.8             4.0                  34.0
# 6                4.8             4.0                  34.0
# 7                4.8             4.0                  34.0
# 8                4.8             4.0                  34.0
# 9                4.8             4.0                  34.0
#
#    valor_colesterol_ldl  valor_colesterol_total  valor_creatina  ...  \
# 0                  56.0                    95.0            0.58  ...
# 1                  72.0                   137.0            0.46  ...
# 2                  86.0                   139.0            0.58  ...
# 3                  86.0                   139.0            0.58  ...
# 4                  74.0                   165.0            0.56  ...
# 5                  86.0                   139.0            0.58  ...
# 6                  86.0                   139.0            0.58  ...
# 7                  86.0                   139.0            0.58  ...
# 8                  86.0                   139.0            0.58  ...
# 9                  86.0                   139.0            0.58  ...
#
#    segundamedicion_peso  segundamedicion_estatura  distancia_rodilla_talon  \
# 0                  64.7                     154.0                     48.5
# 1                  64.7                     154.0                     48.5
# 2                  64.7                     154.0                     48.5
# 3                  64.7                     154.0                     48.5
# 4                  64.7                     154.0                     48.5
# 5                  64.7                     154.0                     48.5
# 6                  64.7                     154.0                     48.5
# 7                  64.7                     154.0                     48.5
# 8                  64.7                     154.0                     48.5
# 9                  64.7                     154.0                     48.5
#
#    circunferencia_de_la_pantorrilla  segundamedicion_cintura  \
# 0                              33.5                      0.0
# 1                              33.5                      0.0
# 2                              33.5                      0.0
# 3                              33.5                      0.0
# 4                              33.5                      0.0
# 5                              33.5                      0.0
# 6                              33.5                      0.0
# 7                              33.5                      0.0
# 8                              33.5                      0.0
# 9                              33.5                      0.0
#
#    tension_arterial  sueno_horas  masa_corporal  actividad_total  \
# 0             111.0          4.0      19.074620            360.0
# 1             102.0          2.0      22.327528            240.0
# 2             165.0          4.0      34.258774            660.0
# 3             123.0          3.0      24.924109            120.0
# 4               0.0          2.0      38.852821            300.0
# 5             115.0          5.0      30.041143            430.0
# 6             101.0          4.0      37.507062            300.0
# 7             113.0          5.0      26.229298            780.0
# 8             151.0          4.0      35.895275            105.0
# 9               0.0          3.0      27.681502            240.0
#
#    riesgo_hipertension
# 0                  0.0
# 1                  0.0
# 2                  1.0
# 3                  1.0
# 4                  1.0
# 5                  1.0
# 6                  1.0
# 7                  1.0
# 8                  1.0
# 9                  1.0
#
# [10 rows x 35 columns]

# %%
dataframe.describe()
# Out:
#               sexo         edad  concentracion_hemoglobina  \
# count  3634.000000  3634.000000                3634.000000
# mean      1.601195    40.564861                  14.241808
# std       0.467393    11.850057                   1.089160
# min       1.000000     4.000000                   5.500000
# 25%       1.000000    31.000000                  14.200000
# 50%       2.000000    42.000000                  14.200000
# 75%       2.000000    50.000000                  14.200000
# max       2.000000    88.000000                  19.900000
#
#        temperatura_ambiente  valor_acido_urico  valor_albumina  \
# count           3634.000000        3634.000000     3634.000000
# mean              21.493366           4.777575        3.910272
# std                2.775534           0.717994        0.383715
# min                6.000000           1.100000        1.500000
# 25%               22.000000           4.800000        4.000000
# 50%               22.000000           4.800000        4.000000
# 75%               22.000000           4.800000        4.000000
# max               35.000000          11.000000        5.200000
#
#        valor_colesterol_hdl  valor_colesterol_ldl  valor_colesterol_total  \
# count           3634.000000           3634.000000             3634.000000
# mean              35.777488             87.007974              142.820567
# std                6.455958             15.136159               24.790561
# min               13.000000             11.000000               44.000000
# 25%               34.000000             86.000000              139.000000
# 50%               34.000000             86.000000              139.000000
# 75%               34.000000             86.000000              139.000000
# max              114.000000            303.000000              681.000000
#
#        valor_creatina  ...  segundamedicion_peso  segundamedicion_estatura  \
# count     3634.000000  ...          3.634000e+03                    3634.0
# mean         0.607560  ...          6.470000e+01                     154.0
# std          0.176263  ...          4.008013e-12                       0.0
# min          0.200000  ...          6.470000e+01                     154.0
# 25%          0.580000  ...          6.470000e+01                     154.0
# 50%          0.580000  ...          6.470000e+01                     154.0
# 75%          0.580000  ...          6.470000e+01                     154.0
# max          8.270000  ...          6.470000e+01                     154.0
#
#        distancia_rodilla_talon  circunferencia_de_la_pantorrilla  \
# count                   3634.0                            3634.0
# mean                      48.5                              33.5
# std                        0.0                               0.0
# min                       48.5                              33.5
# 25%                       48.5                              33.5
# 50%                       48.5                              33.5
# 75%                       48.5                              33.5
# max                       48.5                              33.5
#
#        segundamedicion_cintura  tension_arterial  sueno_horas  masa_corporal  \
# count                   3634.0       3634.000000  3634.000000    3634.000000
# mean                       0.0        116.270844     3.226811      26.403406
# std                        0.0         19.936028     1.936184       5.641145
# min                        0.0          0.000000     1.000000       8.873830
# 25%                        0.0        104.273009     2.092972      22.440850
# 50%                        0.0        115.000000     3.124798      25.641138
# 75%                        0.0        126.000000     4.000000      29.647358
# max                        0.0        200.000000    99.000000      60.513476
#
#        actividad_total  riesgo_hipertension
# count      3634.000000          3634.000000
# mean        521.131067             0.500000
# std         700.921864             0.500069
# min          10.000000             0.000000
# 25%         269.734141             0.000000
# 50%         420.000000             0.500000
# 75%         607.746318             1.000000
# max       17820.000000             1.000000
#
# [8 rows x 35 columns]

# %%
dataframe.groupby('riesgo_hipertension').size()
# Out:
# riesgo_hipertension
# 0.0    1817
# 1.0    1817
# dtype: int64

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3634 entries, 0 to 3633
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   sexo                              3634 non-null   float64
#  1   edad                              3634 non-null   float64
#  2   concentracion_hemoglobina         3634 non-null   float64
#  3   temperatura_ambiente              3634 non-null   float64
#  4   valor_acido_urico                 3634 non-null   float64
#  5   valor_albumina                    3634 non-null   float64
#  6   valor_colesterol_hdl              3634 non-null   float64
#  7   valor_colesterol_ldl              3634 non-null   float64
#  8   valor_colesterol_total            3634 non-null   float64
#  9   valor_creatina                    3634 non-null   float64
#  10  resultado_glucosa                 3634 non-null   float64
#  11  valor_insulina                    3634 non-null   float64
#  12  valor_trigliceridos               3634 non-null   float64
#  13  resultado_glucosa_promedio        3634 non-null   float64
#  14  valor_hemoglobina_glucosilada     3634 non-null   float64
#  15  valor_ferritina                   3634 non-null   float64
#  16  valor_folato                      3634 non-null   float64
#  17  valor_homocisteina                3634 non-null   float64
#  18  valor_proteinac_reactiva          3634 non-null   float64
#  19  valor_transferrina                3634 non-null   float64
#  20  valor_vitamina_bdoce              3634 non-null   float64
#  21  valor_vitamina_d                  3634 non-null   float64
#  22  peso                              3634 non-null   float64
#  23  estatura                          3634 non-null   float64
#  24  medida_cintura                    3634 non-null   float64
#  25  segundamedicion_peso              3634 non-null   float64
#  26  segundamedicion_estatura          3634 non-null   float64
#  27  distancia_rodilla_talon           3634 non-null   float64
#  28  circunferencia_de_la_pantorrilla  3634 non-null   float64
#  29  segundamedicion_cintura           3634 non-null   float64
#  30  tension_arterial                  3634 non-null   float64
#  31  sueno_horas                       3634 non-null   float64
#  32  masa_corporal                     3634 non-null   float64
#  33  actividad_total                   3634 non-null   float64
#  34  riesgo_hipertension               3634 non-null   float64
# dtypes: float64(35)
# memory usage: 993.8 KB

# %%
dataframe.describe()
# Out:
#               sexo         edad  concentracion_hemoglobina  \
# count  3634.000000  3634.000000                3634.000000
# mean      1.601195    40.564861                  14.241808
# std       0.467393    11.850057                   1.089160
# min       1.000000     4.000000                   5.500000
# 25%       1.000000    31.000000                  14.200000
# 50%       2.000000    42.000000                  14.200000
# 75%       2.000000    50.000000                  14.200000
# max       2.000000    88.000000                  19.900000
#
#        temperatura_ambiente  valor_acido_urico  valor_albumina  \
# count           3634.000000        3634.000000     3634.000000
# mean              21.493366           4.777575        3.910272
# std                2.775534           0.717994        0.383715
# min                6.000000           1.100000        1.500000
# 25%               22.000000           4.800000        4.000000
# 50%               22.000000           4.800000        4.000000
# 75%               22.000000           4.800000        4.000000
# max               35.000000          11.000000        5.200000
#
#        valor_colesterol_hdl  valor_colesterol_ldl  valor_colesterol_total  \
# count           3634.000000           3634.000000             3634.000000
# mean              35.777488             87.007974              142.820567
# std                6.455958             15.136159               24.790561
# min               13.000000             11.000000               44.000000
# 25%               34.000000             86.000000              139.000000
# 50%               34.000000             86.000000              139.000000
# 75%               34.000000             86.000000              139.000000
# max              114.000000            303.000000              681.000000
#
#        valor_creatina  ...  segundamedicion_peso  segundamedicion_estatura  \
# count     3634.000000  ...          3.634000e+03                    3634.0
# mean         0.607560  ...          6.470000e+01                     154.0
# std          0.176263  ...          4.008013e-12                       0.0
# min          0.200000  ...          6.470000e+01                     154.0
# 25%          0.580000  ...          6.470000e+01                     154.0
# 50%          0.580000  ...          6.470000e+01                     154.0
# 75%          0.580000  ...          6.470000e+01                     154.0
# max          8.270000  ...          6.470000e+01                     154.0
#
#        distancia_rodilla_talon  circunferencia_de_la_pantorrilla  \
# count                   3634.0                            3634.0
# mean                      48.5                              33.5
# std                        0.0                               0.0
# min                       48.5                              33.5
# 25%                       48.5                              33.5
# 50%                       48.5                              33.5
# 75%                       48.5                              33.5
# max                       48.5                              33.5
#
#        segundamedicion_cintura  tension_arterial  sueno_horas  masa_corporal  \
# count                   3634.0       3634.000000  3634.000000    3634.000000
# mean                       0.0        116.270844     3.226811      26.403406
# std                        0.0         19.936028     1.936184       5.641145
# min                        0.0          0.000000     1.000000       8.873830
# 25%                        0.0        104.273009     2.092972      22.440850
# 50%                        0.0        115.000000     3.124798      25.641138
# 75%                        0.0        126.000000     4.000000      29.647358
# max                        0.0        200.000000    99.000000      60.513476
#
#        actividad_total  riesgo_hipertension
# count      3634.000000          3634.000000
# mean        521.131067             0.500000
# std         700.921864             0.500069
# min          10.000000             0.000000
# 25%         269.734141             0.000000
# 50%         420.000000             0.500000
# 75%         607.746318             1.000000
# max       17820.000000             1.000000
#
# [8 rows x 35 columns]

# %%
import seaborn as sb
sb.catplot(x = 'riesgo_hipertension',data=dataframe,kind="count", height=2.5, aspect=.8)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Cargar el dataset balanceado
balanced_data = pd.read_csv('Hipertension_Arterial_Mexico_balanced.csv')

# Separar características y variable objetivo
y = balanced_data['riesgo_hipertension']
x = balanced_data.drop('riesgo_hipertension', axis=1)

# Dividir en entrenamiento y prueba (si necesitas una nueva partición)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Entrenar un modelo
model = RandomForestClassifier(n_estimators=119, max_depth=5, random_state=42)
model.fit(x_train, y_train)

# Evaluar
predicciones = model.predict(x_test)
clasificadores = ['No tiene', 'Tiene riesgo']
print("Reporte de clasificación:")
print(classification_report(y_test, predicciones, target_names=clasificadores))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#     No tiene       0.95      0.97      0.96       528
# Tiene riesgo       0.97      0.96      0.96       563
#
#     accuracy                           0.96      1091
#    macro avg       0.96      0.96      0.96      1091
# weighted avg       0.96      0.96      0.96      1091

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

sns.heatmap(confusion_matrix(y_test, predicciones), annot=True, fmt="d", xticklabels=clasificadores, yticklabels=clasificadores)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show();

# %%
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

errores = []

# Probar con diferentes cantidades de árboles
for n in range(10, 201, 10):
    modelo = RandomForestClassifier(n_estimators=n, random_state=42)
    modelo.fit(x_train, y_train)
    predicciones = modelo.predict(x_test)
    error = 1 - accuracy_score(y_test, predicciones)  # tasa de error = 1 - accuracy
    errores.append(error)

# Graficar la tasa de error
plt.plot(range(10, 201, 10), errores, marker='o', color='blue')
plt.xlabel('Cantidad de árboles (n_estimators)')
plt.ylabel('Tasa de error')
plt.title('Tasa de error vs. Número de árboles en Random Forest')
plt.grid(True)
plt.show()
